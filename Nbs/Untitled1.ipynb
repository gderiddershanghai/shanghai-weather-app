# %%
import numpy as np

# %%
180-110
# Out:
# 70

# %%
np.mean([6,8,26,4,17,26,8,5,5,5])
# Out:
# np.float64(11.0)

# %%
vals = [6,8,26,4,17,26,8,5,5,5]
np.sum(vals), len(vals)
# Out:
# (np.int64(110), 10)

# %%
165//10.25
# Out:
# 16.0

# %%
132/144, 11/12
# Out:
# (0.9166666666666666, 0.9166666666666666)

# %%
v_cube = 68**3
v_sphere = 4/3*34**3*np.pi

# %%
v_cube-v_sphere
# Out:
# 149795.78979107572

# %%
72*1.5
# Out:
# 108.0

# %%
b = 34
a=1
c=289
b**2 - (4*a*c)
# Out:
# 0

# %%
b**2/4 #- (4*a*c)
# Out:
# 289.0
